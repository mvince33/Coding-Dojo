# %% [markdown]
# <a href="https://colab.research.google.com/github/mvince33/Coding-Dojo/blob/main/week04/styles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.available
plt.style.use('classic')
plt.plot([1, 2], [10,20])

# %%
plt.style.available
plt.style.use('Solarize_Light2')
plt.plot([1, 2], [10, 20])
