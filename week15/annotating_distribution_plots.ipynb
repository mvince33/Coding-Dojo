# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Load the data
df = pd.read_csv('data/medical_data.csv', index_col = 0)
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 1    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 2    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 3    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 4    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 5    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 1    Male        0  ...             0.0       1.0      1.0                1.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3  Female        0  ...             0.0       0.0      0.0                0.0
# 4    Male        0  ...             0.0       0.0      0.0                0.0
# 5  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
# Plot the histogram for income
fig, ax = plt.subplots(figsize = (13, 8));
sns.histplot(df['Income'], ax = ax, stat = 'probability');

# %%
# Get the mean
mean = df['Income'].mean()
mean
# Out:
# 40653.044949999996

# %%
# Plot the histogram for income with vertical line for the mean
fig, ax = plt.subplots(figsize = (13, 8));
sns.histplot(df['Income'], ax = ax, stat = 'probability');
ax.axvline(mean, color = 'red', label = 'Mean');
ax.set_title('Income');
ax.legend();

# %%
# Make the above reproducible
col = 'Income'
feature = df[col]
mean = feature.mean()
fig, ax = plt.subplots(figsize = (13, 8));
sns.histplot(feature, ax = ax, stat = 'probability');
ax.axvline(mean, color = 'red', label = f'Mean = {mean: .2f}');
ax.set_title(f'{col}');
ax.legend();

# %%
col = 'Initial_days'

# %%
feature = df[col]
mean = feature.mean()
fig, ax = plt.subplots(figsize = (13, 8));
sns.histplot(feature, ax = ax, stat = 'probability');
ax.axvline(mean, color = 'red', label = f'Mean = {mean: .2f}');
ax.set_title(f'{col}');
ax.legend();

# %%
# Add the median to the Income histogram
col = 'Income'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig, ax = plt.subplots(figsize = (13, 8));
sns.histplot(feature, ax = ax, stat = 'probability');
ax.axvline(mean, color = 'red', label = f'Mean = {mean: .2f}');
ax.axvline(median, color = 'green', ls = '--', 
           label = f'Median = {median: 0.2f}')
ax.set_title(f'{col}');
ax.legend();

# %%
# Highlight the region between 1 standard deviation from the mean
col = 'Income'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
po_std = mean + std
mo_std = mean - std
fig, ax = plt.subplots(figsize = (13, 8));
sns.histplot(feature, ax = ax, stat = 'probability');
ax.axvline(mean, color = 'red', label = f'Mean = {mean: .2f}');
ax.axvline(median, color = 'green', ls = '--', 
           label = f'Median = {median: 0.2f}');
ax.axvline(po_std, color = 'black', label = f'+1 std: {po_std: 0.2f}');
ax.axvline(mo_std, color = 'black', label = f'-1 std: {mo_std: 0.2f}');
ax.axvspan(mo_std, po_std, color = 'yellow', zorder = 0);
ax.set_title(f'{col}');
ax.legend();
