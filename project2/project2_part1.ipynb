# %% [markdown]
# <a href="https://colab.research.google.com/github/mvince33/Coding-Dojo/blob/main/project2/project2_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2
# - Michael Vincent

# %% [markdown]
# ## Part 1

# %%
# Imports
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data Set 1
#
# 1. My first choice of data set is the "[Secondary Mushroom Dataset](https://archive.ics.uci.edu/ml/datasets/Secondary+Mushroom+Dataset)" data set from UCI
#
# 2. This data consisits of attributes of mushrooms.
#
# 3. The target will be whether the mushroom is poisonous or not.
#
# 4. This is a classification problem.
#
# 5. This data set has 20 features
#
# 6. There are 61069 rows in the data set.
#
# 7. There are missing features so I will have to decide whether to drop the missing rows or use an imputing strategy. Some features have thousands of missing values which could pose some challenges. There are quite a few features with no missing values so I will still be able to apply the techniques we've covered to this data set.

# %%
# Load the data
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSu_3xbzvwqg6MpBKKDB3u8YHK31h6CTK5z1MClZorpRvHz4gTYJdv3IrrdSzwBA3gHuxlY7hsShEpZ/pub?output=csv'
df = pd.read_csv(url)
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
# Explore the data
print('There are ', df.shape[0], 'data points, and', (df.shape[1] - 1), 'features.')
print('There are', df.duplicated().sum(), 'duplicates in the data set.')
print('There are', df.isna().sum().sum(), 'missing values in the data set.')

df.isna().sum()
# Out:
# There are  61069 data points, and 20 features.
# There are 146 duplicates in the data set.
# There are 307463 missing values in the data set.
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9884
# gill-spacing            25063
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51538
# stem-surface            38124
# stem-color                  0
# veil-type               57892
# veil-color              53656
# has-ring                    0
# ring-type                2471
# spore-print-color       54715
# habitat                     0
# season                      0
# dtype: int64

# %% [markdown]
# ### Data Set 2

# %% [markdown]
# 1. My second choice of data set is the ["Cervical cancer (Risk Factors)"](https://archive.ics.uci.edu/ml/datasets/Cervical+cancer+%28Risk+Factors%29#) data set from UCI.
#
# 2. This dataset consists of information about patients
#
# 3. The target will be whether or not a person has cervical cancer.
#
# 4. This is a classification problem.
#
# 5. This data set has 35 features.
#
# 6. This data set has 858 data points.
#
# 7. There are no missing values, but there are some inconistent labels that will need to be dealt with.

# %%
# Load the data
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQ433NVfMv-r932OU8uHTz62jta6vZVW9D4UfnsVhNMO8u1ey5WCQlacyq0-Z32Axny_YiK2v4NpwCc/pub?output=csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Age Age.Group  Gender Locality Marital status Life.Style Sleep Category  \
# 0   45     41-50  Female    RURAL        MARRIED         NO    NO     FREE
# 1   51     51-60  Female    URBAN        MARRIED         NO    NO     FREE
# 2   55     51-60  Female    RURAL        MARRIED        YES   YES     FREE
# 3   55     51-60  Female    RURAL        MARRIED        YES   YES     FREE
# 4   56     51-60  Female    RURAL        MARRIED        YES    NO     FREE
#
#   Depression Hyperlipi  ... oldpeak slope  ca  thal num SK  SK.React  \
# 0        YES       YES  ...     3.0     2   0     7   2  1        NO
# 1        YES       YES  ...     1.2     2   0     7   2  1        NO
# 2        YES       YES  ...     3.4     2   0     3   2  1        NO
# 3        YES       YES  ...     2.0     2   1     7   3  1        NO
# 4        YES       YES  ...     4.0     3   2     7   3  1        NO
#
#    Reaction  Mortality  Follow.Up
# 0         0          0         60
# ...

# %%
# Explore the data
print('There are ', df.shape[0], 'data points, and', (df.shape[1] - 1), 'features.')
print('There are', df.duplicated().sum(), 'duplicates in the data set.')
print('There are', df.isna().sum().sum(), 'missing values in the data set.')

# Show the various labels used for the categorical data
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
for col in cat_cols:
  print('\nColumn:', col)
  print(df[col].value_counts())
# Out:
# There are  368 data points, and 59 features.
# There are 214 duplicates in the data set.
# There are 0 missing values in the data set.
#
# Column: Age.Group
# 51-60    184
# 61-70     91
# 41-50     61
# 31-40     20
# 21-30     12
# Name: Age.Group, dtype: int64
#
# Column: Gender
# Male      285
# Female     83
# Name: Gender, dtype: int64
#
# Column: Locality
# URBAN    234
# RURAL    134
# Name: Locality, dtype: int64
#
# Column: Marital status
# MARRIED    365
# SINGLE       3
# Name: Marital status, dtype: int64
#
# Column: Life.Style
# YES    217
# NO     151
# Name: Life.Style, dtype: int64
#
# Column: Sleep
# NO     224
# YES    144
# Name: Sleep, dtype: int64
#
# Column: Category
# FREE    331
# PAID     37
# Name: Category, dtype: int64
#
# Column: Depression
# YES    351
# NO      17
# Name: Depression, dtype: int64
#
# Column: Hyperlipi
# YES    341
# NO      27
# Name: Hyperlipi, dtype: int64
#
# Column: Smoking
# YES    195
# NO     173
# Name: Smoking, dtype: int64
#
# ...
