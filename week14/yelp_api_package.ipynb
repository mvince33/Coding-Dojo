# %%
# Imports
import numpy as np
import pandas as pd
import json
from yelpapi import YelpAPI

# %%
# Get the API key
with open('yelp_api.json') as f:
    login = json.load(f)

# %%
# Instantiate an instance of the YelpAPI
yelp_api = YelpAPI(login['api-key'], timeout_s = 5.0)
yelp_api

# %%
# Getting help
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# Make a query
search_results = yelp_api.search_query(location = 'NY, NY', 
                                       term = 'Pizza')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
# See how many search results there are
search_results['total']
# Out:
# 12100

# %%
# Put the business info into a data frame
biz = pd.DataFrame(search_results['businesses'])
biz.head()
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  tpcCX_SHaNXqAzXOzbluJQ             fini-pizza-brooklyn
# 2  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 3  v1DHGRNCH9247WLYoaoA9A   l-industrie-pizzeria-brooklyn
# 4  uc5qQMzs96rzjK27epDCug           joes-pizza-new-york-4
#
#                    name                                          image_url  \
# 0   Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/HVjttL...
# 1            Fini Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/ZJjnBs...
# 2             Juliana's  https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4n...
# 3  L'industrie Pizzeria  https://s3-media3.fl.yelpcdn.com/bphoto/Llq71W...
# 4           Joe's Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4499
# 1      False  https://www.yelp.com/biz/fini-pizza-brooklyn?a...            10
# 2      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2522
# 3      False  https://www.yelp.com/biz/l-industrie-pizzeria-...           762
# 4      False  https://www.yelp.com/biz/joes-pizza-new-york-4...          2874
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 3             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 4             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 1     {'latitude': 40.71348, 'longitude': -73.96182}                  []
# 2  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 3     {'latitude': 40.71162, 'longitude': -73.95783}          [delivery]
# 4  {'latitude': 40.73060076, 'longitude': -74.002...          [delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1   NaN  {'address1': '305 Bedford Ave', 'address2': ''...
# 2    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 3     $  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 4     $  {'address1': '7 Carmine St', 'address2': '', '...  +12123661182
#
#     display_phone     distance
# 0  (212) 966-4100  1961.877142
# 1                  2882.711683
# 2  (718) 596-6700   308.569844
# 3  (718) 599-0002  3145.016041
# 4  (212) 366-1182  2874.702514

# %%
# Check the number of results in the business dictionary
len(biz)
# Out:
# 20

# %%
# Get the next 20 results
search_results = yelp_api.search_query(location = 'NY, NY', 
                                       term = 'Pizza',
                                       offset = 20)

# %%
# Put the next page of results in a data frame
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head()
# Out:
#                        id                                alias  \
# 0  oOr6Ta5gZyDl6PyZ1cq7pg          east-village-pizza-new-york
# 1  vpkTNjq9dRh9rT3Nh0pe-A              nolita-pizza-new-york-2
# 2  vfYhEpp0x-DrNjC6GSJjPQ  artichoke-basilles-pizza-new-york-2
# 3  zaoZrYftFSEWnoXe3Xsolg                     x-pizza-new-york
# 4  pGr5QuQU7Ur5GHLvXbT8bw                 paulie-gees-brooklyn
#
#                         name  \
# 0         East Village Pizza
# 1               Nolita Pizza
# 2  Artichoke Basille's Pizza
# 3                    X Pizza
# 4               Paulie Gee's
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/JiV117...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/iY3qXR...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/4krjwP...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/562tMr...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/1j39J4...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/east-village-pizza-ne...           438
# 1  https://www.yelp.com/biz/nolita-pizza-new-york...           158
# 2  https://www.yelp.com/biz/artichoke-basilles-pi...          4120
# 3  https://www.yelp.com/biz/x-pizza-new-york?adju...             1
# 4  https://www.yelp.com/biz/paulie-gees-brooklyn?...          1319
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 3             [{'alias': 'pizza', 'title': 'Pizza'}]     3.0
# 4             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                          coordinates        transactions  \
# 0   {'latitude': 40.728199, 'longitude': -73.985182}  [pickup, delivery]
# 1  {'latitude': 40.7208883, 'longitude': -73.9962...  [pickup, delivery]
# 2  {'latitude': 40.7321124557704, 'longitude': -7...  [pickup, delivery]
# 3  {'latitude': 40.70669773150677, 'longitude': -...  [pickup, delivery]
# 4   {'latitude': 40.729546, 'longitude': -73.958568}          [delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '145 1st Ave', 'address2': '', 'a...  +12125294545
# 1     $  {'address1': '68 Kenmare St', 'address2': None...  +16468959131
# 2     $  {'address1': '321 E 14th St', 'address2': '', ...  +12122282004
# 3   NaN  {'address1': '190 Front St', 'address2': '', '...
# 4    $$  {'address1': '60 Greenpoint Ave', 'address2': ...  +13479873747
#
#     display_phone     distance
# 0  (212) 529-4545  2643.857504
# 1  (646) 895-9131  1725.054309
# 2  (212) 228-2004  3091.822114
# 3                   853.447905
# 4  (347) 987-3747  4027.308251

# %%
# Combine the search results into one data frame
businesses = pd.concat([biz, biz20], ignore_index = True)
display(businesses.head(), businesses.tail())
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  tpcCX_SHaNXqAzXOzbluJQ             fini-pizza-brooklyn
# 2  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 3  v1DHGRNCH9247WLYoaoA9A   l-industrie-pizzeria-brooklyn
# 4  uc5qQMzs96rzjK27epDCug           joes-pizza-new-york-4
#
#                    name                                          image_url  \
# 0   Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/HVjttL...
# 1            Fini Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/ZJjnBs...
# 2             Juliana's  https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4n...
# 3  L'industrie Pizzeria  https://s3-media3.fl.yelpcdn.com/bphoto/Llq71W...
# 4           Joe's Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4499
# 1      False  https://www.yelp.com/biz/fini-pizza-brooklyn?a...            10
# 2      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2522
# 3      False  https://www.yelp.com/biz/l-industrie-pizzeria-...           762
# 4      False  https://www.yelp.com/biz/joes-pizza-new-york-4...          2874
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 3             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 4             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 1     {'latitude': 40.71348, 'longitude': -73.96182}                  []
# 2  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 3     {'latitude': 40.71162, 'longitude': -73.95783}          [delivery]
# 4  {'latitude': 40.73060076, 'longitude': -74.002...          [delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1   NaN  {'address1': '305 Bedford Ave', 'address2': ''...
# 2    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 3     $  {'address1': '254 S 2nd St', 'address2': '', '...  +17185990002
# 4     $  {'address1': '7 Carmine St', 'address2': '', '...  +12123661182
#
#     display_phone     distance
# 0  (212) 966-4100  1961.877142
# 1                  2882.711683
# 2  (718) 596-6700   308.569844
# 3  (718) 599-0002  3145.016041
# 4  (212) 366-1182  2874.702514
#                         id                                  alias  \
# 35  cS2dquz8jSagXqeVKBwSsg                 fascati-pizza-brooklyn
# 36  UB1mGugr1pvgUUP1eTNXrg  stone-bridge-pizza-and-salad-new-york
# 37  aTmNnrx0XE_nTSFFzXnt8w                roebling-pizza-brooklyn
# 38  RfFXF-Momn0tLIgh1TZKLw               di-fara-pizza-new-york-2
# 39  affWh2WFSMayL04l9lr47g                     roberta-s-brooklyn
#
#                           name  \
# 35               Fascati Pizza
# 36  Stone Bridge Pizza & Salad
# 37              Roebling Pizza
# 38               Di Fara Pizza
# 39                   Roberta’s
#
#                                             image_url  is_closed  \
# 35  https://s3-media1.fl.yelpcdn.com/bphoto/qLIpIv...      False
# 36  https://s3-media1.fl.yelpcdn.com/bphoto/yfY3OA...      False
# 37  https://s3-media3.fl.yelpcdn.com/bphoto/CqDPm-...      False
# 38  https://s3-media3.fl.yelpcdn.com/bphoto/SaWdpz...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/rdK-so...      False
#
#                                                   url  review_count  \
# 35  https://www.yelp.com/biz/fascati-pizza-brookly...           256
# 36  https://www.yelp.com/biz/stone-bridge-pizza-an...           306
# 37  https://www.yelp.com/biz/roebling-pizza-brookl...           132
# 38  https://www.yelp.com/biz/di-fara-pizza-new-yor...            15
# 39  https://www.yelp.com/biz/roberta-s-brooklyn?ad...             9
#
#                                            categories  rating  \
# 35  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 36  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 37             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 38             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 39             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                           coordinates        transactions  \
# 35      {'latitude': 40.6985, 'longitude': -73.99273}          [delivery]
# 36     {'latitude': 40.75225, 'longitude': -73.98061}  [pickup, delivery]
# 37  {'latitude': 40.7084890714263, 'longitude': -7...  [pickup, delivery]
# 38  {'latitude': 40.706894091267536, 'longitude': ...  [pickup, delivery]
# 39  {'latitude': 40.71613781459604, 'longitude': -...                  []
#
#    price                                           location         phone  \
# 35     $  {'address1': '80 Henry St', 'address2': '', 'a...  +17182371278
# 36    $$  {'address1': '16 E 41st St', 'address2': None,...  +16467915690
# 37     $  {'address1': '326 Roebling St', 'address2': ''...  +17187825042
# 38   NaN  {'address1': '108 South St', 'address2': '', '...  +19173883130
# 39   NaN  {'address1': '6 Grand St', 'address2': '', 'ad...
#
#      display_phone     distance
# 35  (718) 237-1278   783.489637
# 36  (646) 791-5690  5333.518248
# 37  (718) 782-5042  2818.813122
# 38  (917) 388-3130   657.021625
# 39                  2620.492306
